# %%
#import dependencies

import pandas as pd

# %%
#data loading
data_1 = pd.read_csv("JC-201901-citibike-tripdata.csv", error_bad_lines=False)
data_2 = pd.read_csv("JC-201902-citibike-tripdata.csv", error_bad_lines=False)
data_3 = pd.read_csv("JC-201903-citibike-tripdata.csv", error_bad_lines=False)
data_4 = pd.read_csv("JC-201904-citibike-tripdata.csv", error_bad_lines=False)
data_5 = pd.read_csv("JC-201905-citibike-tripdata.csv", error_bad_lines=False)
data_6 = pd.read_csv("JC-201906-citibike-tripdata.csv", error_bad_lines=False)
data_7 = pd.read_csv("JC-201907-citibike-tripdata.csv", error_bad_lines=False)
data_8 = pd.read_csv("JC-201908-citibike-tripdata.csv", error_bad_lines=False)
data_9 = pd.read_csv("JC-201909-citibike-tripdata.csv", error_bad_lines=False)
data_10 = pd.read_csv("JC-201910-citibike-tripdata.csv", error_bad_lines=False)
data_11 = pd.read_csv("JC-201911-citibike-tripdata.csv", error_bad_lines=False)
data_12 = pd.read_csv("JC-201912-citibike-tripdata.csv", error_bad_lines=False)

# %%
connected_data = [data_1,data_2,data_3,data_4,data_5,data_6,data_7,data_8,data_9,data_10,data_11,data_12]

# %%
citi_results = pd.concat(connected_data)
citi_results.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...
